# %% [markdown]
# ## <font color='blue'>Infraestrutura de Dados, IA e Agentes de IA com Databricks</font>
# ### <font color='blue'>Automatizando o Pipeline de Consolidação, Limpeza e Enriquecimento de Dados no Databricks</font>

# %% [markdown]
# ## Tabela Gold Para Análise dos Dados

# %% [markdown]
# Quais segmentos de clientes (com base no tipo de cliente e país) contribuem mais para a receita total e como isso varia entre os métodos de pagamento?

# %%
# Define o banco de dados a ser usado
spark.sql(" use db_03_final")

# %%
# Cria a tabela gold para análise
spark.sql("""
create or replace table gold_table_segmentos_clientes as 
select 
    c.customer_type,
    c.country,
    o.payment_method,
    round(sum(o.total_amount), 2) as total_revenue
from 
    db_02_staging.silver_transacoes as o
join 
    db_02_staging.silver_clientes as c 
on 
    o.customer_id = c.customer_id
group by 
    c.customer_type,
    c.country,
    o.payment_method
order by 
    total_revenue desc
""")

# %%
# %sql
select * from gold_table_segmentos_clientes;

# %% [markdown]
# # Fim
